# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("/Users/behrad/Documents/imt tmrin/EnglandWeather.csv")
data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0             9.472222            14.1197               1015.13      0.89
# ...

# %%
new =data['Formatted Date'].str.split(' ',n=2, expand=True)
new
# Out:
#                 0             1      2
# 0      2006-04-01  00:00:00.000  +0200
# 1      2006-04-01  01:00:00.000  +0200
# 2      2006-04-01  02:00:00.000  +0200
# 3      2006-04-01  03:00:00.000  +0200
# 4      2006-04-01  04:00:00.000  +0200
# ...           ...           ...    ...
# 96448  2016-09-09  19:00:00.000  +0200
# 96449  2016-09-09  20:00:00.000  +0200
# 96450  2016-09-09  21:00:00.000  +0200
# 96451  2016-09-09  22:00:00.000  +0200
# 96452  2016-09-09  23:00:00.000  +0200
#
# [96453 rows x 3 columns]

# %%
data1=data.drop(columns=['Formatted Date'])
data1
# Out:
#              Summary Precip Type  Temperature (C)  Wind Speed (km/h)  \
# 0      Partly Cloudy        rain         9.472222            14.1197
# 1      Partly Cloudy        rain         9.355556            14.2646
# 2      Mostly Cloudy        rain         9.377778             3.9284
# 3      Partly Cloudy        rain         8.288889            14.1036
# 4      Mostly Cloudy        rain         8.755556            11.0446
# ...              ...         ...              ...                ...
# 96448  Partly Cloudy        rain        26.016667            10.9963
# 96449  Partly Cloudy        rain        24.583333            10.0947
# 96450  Partly Cloudy        rain        22.038889             8.9838
# 96451  Partly Cloudy        rain        21.522222            10.5294
# 96452  Partly Cloudy        rain        20.438889             5.8765
#
#        Pressure (millibars)  Humidity
# 0                   1015.13      0.89
# 1                   1015.63      0.86
# ...

# %%
data1.insert(0,'Date',new[0])
data1
# Out:
#              Date        Summary Precip Type  Temperature (C)  \
# 0      2006-04-01  Partly Cloudy        rain         9.472222
# 1      2006-04-01  Partly Cloudy        rain         9.355556
# 2      2006-04-01  Mostly Cloudy        rain         9.377778
# 3      2006-04-01  Partly Cloudy        rain         8.288889
# 4      2006-04-01  Mostly Cloudy        rain         8.755556
# ...           ...            ...         ...              ...
# 96448  2016-09-09  Partly Cloudy        rain        26.016667
# 96449  2016-09-09  Partly Cloudy        rain        24.583333
# 96450  2016-09-09  Partly Cloudy        rain        22.038889
# 96451  2016-09-09  Partly Cloudy        rain        21.522222
# 96452  2016-09-09  Partly Cloudy        rain        20.438889
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0                14.1197               1015.13      0.89
# 1                14.2646               1015.63      0.86
# ...

# %%
new1 =data1['Date'].str.split('-',n=1, expand=True)
new1
# Out:
#           0      1
# 0      2006  04-01
# 1      2006  04-01
# 2      2006  04-01
# 3      2006  04-01
# 4      2006  04-01
# ...     ...    ...
# 96448  2016  09-09
# 96449  2016  09-09
# 96450  2016  09-09
# 96451  2016  09-09
# 96452  2016  09-09
#
# [96453 rows x 2 columns]

# %%
data1.insert(1,'Year',new1[0])
data1
# Out:
#              Date  Year        Summary Precip Type  Temperature (C)  \
# 0      2006-04-01  2006  Partly Cloudy        rain         9.472222
# 1      2006-04-01  2006  Partly Cloudy        rain         9.355556
# 2      2006-04-01  2006  Mostly Cloudy        rain         9.377778
# 3      2006-04-01  2006  Partly Cloudy        rain         8.288889
# 4      2006-04-01  2006  Mostly Cloudy        rain         8.755556
# ...           ...   ...            ...         ...              ...
# 96448  2016-09-09  2016  Partly Cloudy        rain        26.016667
# 96449  2016-09-09  2016  Partly Cloudy        rain        24.583333
# 96450  2016-09-09  2016  Partly Cloudy        rain        22.038889
# 96451  2016-09-09  2016  Partly Cloudy        rain        21.522222
# 96452  2016-09-09  2016  Partly Cloudy        rain        20.438889
#
#        Wind Speed (km/h)  Pressure (millibars)  Humidity
# 0                14.1197               1015.13      0.89
# ...

# %%
df=data1.sort_values(by='Date')
datamean= df.groupby(pd.Grouper(key='Date'),as_index=False).mean()
datamean
# Out:
#             Date  Temperature (C)  Wind Speed (km/h)  Pressure (millibars)  \
# 0     2006-01-01         3.873148          21.372750           1012.279167
# 1     2006-01-02         5.418519          17.551683           1010.131667
# 2     2006-01-03         2.319444           8.417617           1020.805000
# 3     2006-01-04         2.274074          11.579925            981.826667
# 4     2006-01-05         2.698148           9.515100            935.988333
# ...          ...              ...                ...                   ...
# 4013  2016-12-27         0.280324          10.980200           1020.304583
# 4014  2016-12-28         0.224306          10.969467           1020.334583
# 4015  2016-12-29         0.169676          10.892992           1020.365833
# 4016  2016-12-30         0.119444          10.806454           1020.395000
# 4017  2016-12-31         0.072454          10.764862           1020.423750
#
#       Humidity
# 0     0.818333
# 1     0.844583
# 2     0.898333
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96453 entries, 2902 to 89716
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  96453 non-null  object
#  1   Year                  96453 non-null  object
#  2   Summary               96453 non-null  object
#  3   Precip Type           95936 non-null  object
#  4   Temperature (C)       96453 non-null  float64
#  5   Wind Speed (km/h)     96453 non-null  float64
#  6   Pressure (millibars)  96453 non-null  float64
#  7   Humidity              96453 non-null  float64
# dtypes: float64(4), object(4)
# memory usage: 6.6+ MB

# %%
df.describe()
# Out:
#        Temperature (C)  Wind Speed (km/h)  Pressure (millibars)      Humidity
# count     96453.000000       96453.000000          96453.000000  96453.000000
# mean         11.932678          10.810640           1003.235956      0.734899
# std           9.551546           6.913571            116.969906      0.195473
# min         -21.822222           0.000000              0.000000      0.000000
# 25%           4.688889           5.828200           1011.900000      0.600000
# 50%          12.000000           9.965900           1016.450000      0.780000
# 75%          18.838889          14.135800           1021.090000      0.890000
# max          39.905556          63.852600           1046.380000      1.000000

# %%
sns.lmplot(x='Wind Speed (km/h)', y='Humidity',ci=None,hue='Precip Type' ,data=df)
plt.show()

# %%
plt.scatter(df['Temperature (C)'],df['Humidity'])
plt.xlabel('Temperature (C)')
plt.ylabel('Humidity')
plt.grid()
plt.show()

# %%
plt.scatter(df['Temperature (C)'],df['Humidity'])
plt.xlabel('Temperature (C)')
plt.ylabel('Humidity')
plt.grid()
plt.show()

# %%
plt.scatter(df['Pressure (millibars)'],df['Humidity'])
plt.xlabel('Pressure (millibars)')
plt.ylabel('Humidity')
plt.grid()
plt.show()

# %%
plt.scatter(df['Summary'],df['Humidity'])
plt.xlabel('Summary')
plt.ylabel('Humidity')
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
Year_mean_Humidty =df.groupby('Year').apply(lambda x : x.Humidity.mean())
Year_mean_Humidty
# Out:
# Year
# 2006    0.767341
# 2007    0.689652
# 2008    0.701237
# 2009    0.707247
# 2010    0.796858
# 2011    0.736017
# 2012    0.689500
# 2013    0.754209
# 2014    0.748578
# 2015    0.732355
# 2016    0.760874
# dtype: float64

# %%
Summary_Humidty =df.groupby('Summary').apply(lambda x : x.Humidity.mean())
Summary_Humidty
# Out:
# Summary
# Breezy                                 0.637778
# Breezy and Dry                         0.260000
# Breezy and Foggy                       0.938571
# Breezy and Mostly Cloudy               0.637054
# Breezy and Overcast                    0.763144
# Breezy and Partly Cloudy               0.545803
# Clear                                  0.729708
# Dangerously Windy and Partly Cloudy    0.490000
# Drizzle                                0.867949
# Dry                                    0.230294
# Dry and Mostly Cloudy                  0.242143
# Dry and Partly Cloudy                  0.240814
# Foggy                                  0.950765
# Humid and Mostly Cloudy                0.874250
# Humid and Overcast                     0.881429
# Humid and Partly Cloudy                0.848824
# Light Rain                             0.888095
# Mostly Cloudy                          0.725069
# Overcast                               0.837232
# ...

# %%
price_extremes = r=df.groupby("Date").Humidity.agg([min,max])
price_extremes
# Out:
#              min   max
# Date
# 2006-01-01  0.72  0.89
# 2006-01-02  0.73  0.99
# 2006-01-03  0.84  0.95
# 2006-01-04  0.84  0.96
# 2006-01-05  0.92  1.00
# ...          ...   ...
# 2016-12-27  0.83  0.95
# 2016-12-28  0.83  0.95
# 2016-12-29  0.83  0.95
# 2016-12-30  0.83  0.95
# 2016-12-31  0.83  0.95
#
# [4018 rows x 2 columns]

# %%
sns.barplot(x=df['Year'],y=df['Humidity'])
plt.show()
